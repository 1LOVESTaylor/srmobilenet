# %%
from PIL import Image
import os
import numpy as np
import cv2
import torch
from torch.autograd import Variable
import pickle as pk
import logging
import visdom

# %%
class Option(object):
    def __init__(self):
        pass

# %%
opt = Option()
opt.max_epochs = 100
opt.gpu_ids = [0]
opt.task = 'test'
opt.display_port = 8097
opt.num_images_per_batch = 1
opt.save_dir = '/home/guang/SuperRes/pytorch-srgan/test/'
opt.pretrained_state = '/home/guang/SuperRes/pytorch-srgan/snapshots/perform_test/state_epoch100_iter0.pkl' 
opt.snapshot_subdir = 'test01'  # 'nightingale'
opt.snapshot_prefix_G = 'unet256'
opt.snapshot_prefix_D = 'basic'
opt.snapshot_interval_epochs = 10 # In epochs
opt.snapshot_interval_iters = 5000
opt.display_interval = 1  # In iterations
opt.display_env = opt.snapshot_subdir
opt.num_average_minibatches = None 
opt.learning_rate = 1e-4
opt.lambda_G = 1e-3
opt.no_lsgan = True
opt.dataset = 'test' #'test' #'starcraft1688' #'ilsvrc2012'
opt.num_crops_per_image = 1 # should be the same value as num_images_per_batch
opt.log_file = os.path.join('/home/guang/SuperRes/pytorch-srgan/test/', 
                            opt.snapshot_subdir,
                            'log.txt')
opt.eval_dir = os.path.join('/home/guang/SuperRes/evaluation/SRGAN/')

opt.save_dir = os.path.join(opt.save_dir, opt.snapshot_subdir)
if not os.path.isdir(opt.save_dir):
    os.makedirs(opt.save_dir)
if not os.path.isdir(opt.eval_dir):
    os.makedirs(opt.eval_dir)

# %%
logger = logging.getLogger("pytorch-srgan")
logger.setLevel(logging.DEBUG)
logger.propagate = False

log_file = logging.FileHandler(opt.log_file)
log_file.setLevel(logging.DEBUG)

fmt = '%(asctime)s %(levelname)-8s: %(message)s'
fmt = logging.Formatter(fmt)

log_file.setFormatter(fmt)
logger.addHandler(log_file)

logger.info('Pretrained state "{}"'.format(opt.pretrained_state))
logger.info('Snapshot will be saved in "{}"'.format(opt.save_dir))

# %%
from models.networks import define_D, GANLoss, define_G

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 1e-2)

# %%
#TODO no_lsgan and use sigmoid
opt.use_sigmoid = opt.no_lsgan
model_D = define_D(6, 64, 'basic', use_sigmoid=opt.use_sigmoid)
model_G = define_G(3, 3, 64, which_model_netG='unet_256')

loss_history = {
    'L2_loss': [],
    'Gan_G_loss': [], 
    'D_loss_real': [],
    'D_loss_fake': [],
}

if opt.pretrained_state is None:
    state = {
        'loss_history': {
            'L2_loss': [],
            'Gan_G_loss': [], 
            'D_loss_real': [],
            'D_loss_fake': [],
        },
        'model_G': None,
        'model_D': None,
        'optimizer_G': None,
        'optimizer_D': None,        
        
        'epochs': 0
    }
    model_G.apply(weights_init)
    model_D.apply(weights_init)
    model_G.cuda(device=opt.gpu_ids[0])
    model_D.cuda(device=opt.gpu_ids[0])
    optimizer_G = torch.optim.Adam(model_G.parameters(), lr=opt.learning_rate)
    optimizer_D = torch.optim.Adam(model_D.parameters(), lr=opt.learning_rate)

else:
    with open(opt.pretrained_state) as f:
        state = pk.load(f)
    model_G.load_state_dict(torch.load(os.path.join(os.path.dirname(opt.pretrained_state), state['model_G'])))
    model_D.load_state_dict(torch.load(os.path.join(os.path.dirname(opt.pretrained_state), state['model_D'])))
    model_G.cuda(device=opt.gpu_ids[0])
    model_D.cuda(device=opt.gpu_ids[0])
    optimizer_G = torch.optim.Adam(model_G.parameters(), lr=opt.learning_rate)
    optimizer_D = torch.optim.Adam(model_D.parameters(), lr=opt.learning_rate)
    optimizer_G.load_state_dict(torch.load(os.path.join(os.path.dirname(opt.pretrained_state), state['optimizer_G'])))
    optimizer_D.load_state_dict(torch.load(os.path.join(os.path.dirname(opt.pretrained_state), state['optimizer_D'])))   
    
loss_history = state['loss_history']
Tensor = torch.cuda.FloatTensor

# %%
# Load the dataset
if opt.dataset == 'ilsvrc2012':
    from datasets.ilsvrc2012 import ILSVRC2012
    ilsvrc = ILSVRC2012('/home/guang/datasets/ILSVRC2012', N=opt.num_crops_per_image, scales=[2,3,4])
    dataset = torch.utils.data.DataLoader(
                ilsvrc,
                batch_size=opt.num_images_per_batch,
                num_workers=int(1),
                shuffle=True)
elif opt.dataset == 'starcraft1688':
    from datasets.starcraft1688 import StarCraft1688Dataset
    starcraft = StarCraft1688Dataset('/home/guang/datasets/starcraft1688', N=opt.num_crops_per_image)
    dataset = torch.utils.data.DataLoader(
                starcraft,
                batch_size=opt.num_images_per_batch,
                num_workers=int(1),
                shuffle=True)
    n_image_pairs = len(starcraft)    
elif opt.dataset == 'test':
    from datasets.testset import testset
    testset = testset('/home/guang/datasets/starcraft_scene2', N=opt.num_images_per_batch)
    dataset = torch.utils.data.DataLoader(
                testset,
                batch_size=opt.num_images_per_batch,
                num_workers=int(1),
                shuffle=True)
    n_image_pairs = len(testset) 
    print('Test images in total: {}').format(n_image_pairs)
    
if opt.num_average_minibatches is None:
    opt.num_average_minibatches = len(dataset)
# Out:
# Test images in total: 244

# %%
from torch.nn import functional as F
def center_crop(x, height, width):
    crop_h = torch.FloatTensor([x.size()[2]]).sub(height).div(-2)
    crop_w = torch.FloatTensor([x.size()[3]]).sub(width).div(-2)

    return F.pad(x, [
        crop_w.ceil().int()[0], crop_w.floor().int()[0],
        crop_h.ceil().int()[0], crop_h.floor().int()[0],
    ])

# %%
import progressbar as pb
import scipy.misc
from Quality import PSNR, SSIM 
import time

input_tensor = Tensor(1, 3, 512, 512)
target_tensor = Tensor(1, 3, 512, 512)
# label_fake = Variable(Tensor(opt.batch_size).fill_(0))
# label_real = Variable(Tensor(opt.batch_size;t).fill_(1))

psnr, ssim = [], []
time_points = []
for minibatch_i, data in enumerate(dataset):

    # Stacking crops together as different inputs/targets
    input_data = []
    target_data = []
    for crop_i in range(opt.num_crops_per_image):
        input_data.append(data[crop_i*2])
        target_data.append(data[crop_i*2+1])
    input_data = torch.cat(input_data, dim=0)    
    target_data = torch.cat(target_data, dim=0)
    
    input_tensor.resize_(input_data.size()).copy_(input_data)
    target_tensor.resize_(target_data.size()).copy_(target_data)
    input = Variable(input_tensor)
    target = Variable(target_tensor)
    
    crop_h, crop_w = 360, 640
    start = time.time()
    output = model_G.forward(input)
    point = time.time() - start
    time_points.append(point)
    print('Testing cost time in {:.0f}m {:.0f}s\n'.format(point // 60, point % 60))
    
    #psnr.append(PSNR(output.data.cpu().numpy(), target.data.cpu().numpy()))
    #ssim.append(SSIM(Variable(output.data.cpu()), Variable(target.data.cpu())))
    
    output = center_crop(output, crop_h, crop_w)
    output = output.data.cpu().numpy()
    
    mean = [ 0.5, 0.5, 0.5 ]
    std = [ 0.5, 0.5, 0.5 ]
    for c in range(3):
        pass
        output[:, c, :, :] *= std[c]
        output[:, c, :, :] += mean[c]
            
    for save_i in range(opt.num_images_per_batch):
        im_np = output[save_i,:,:,:]
        scipy.misc.imsave(os.path.join(opt.save_dir, 'test_{}.bmp'.format(minibatch_i*opt.num_crops_per_image+save_i)), im_np)

#print psnr
#print ssim
np.save(os.path.join(opt.eval_dir, "time.npy"), time_points)
print time_points
print len(time_points), np.mean(time_points)
# Out:
# Testing cost time in 0m 3s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# Testing cost time in 0m 0s
#
# [2.8127119541168213, 0.003587007522583008, 0.0034592151641845703, 0.004023075103759766, 0.00335693359375, 0.0036749839782714844, 0.0034770965576171875, 0.0035719871520996094, 0.003926992416381836, 0.0037870407104492188, 0.0037801265716552734, 0.0034317970275878906, 0.0034029483795166016, 0.0036280155181884766, 0.0034990310668945312, 0.003462076187133789, 0.004055023193359375, 0.0035140514373779297, 0.004164934158325195, 0.0038139820098876953, 0.003513813018798828, 0.00432586669921875, 0.0034258365631103516, 0.0024271011352539062, 0.0028438568115234375, 0.0024619102478027344, 0.0025348663330078125, 0.0026900768280029297, 0.002732992172241211, 0.0037589073181152344, 0.003081798553466797, 0.003960132598876953, 0.0032291412353515625, 0.005140066146850586, 0.006646871566772461, 0.0032939910888671875, 0.0028409957885742188, 0.0036749839782714844, 0.0025811195373535156, 0.002856016159057617, 0.004578113555908203, 0.0038259029388427734, 0.004244089126586914, 0.003983020782470703, 0.003621816635131836, 0.003920078277587891, 0.003893136978149414, 0.0027480125427246094, 0.004224061965942383, 0.003170013427734375, 0.0025370121002197266, 0.0024759769439697266, 0.0031027793884277344, 0.0025539398193359375, 0.002740144729614258, 0.0038170814514160156, 0.002527952194213867, 0.0037369728088378906, 0.002577066421508789, 0.0026209354400634766, 0.0036318302154541016, 0.004563808441162109, 0.003473997116088867, 0.0027098655700683594, 0.00444793701171875, 0.002908945083618164, 0.0024728775024414062, 0.003409147262573242, 0.004202127456665039, 0.004571199417114258, 0.004571199417114258, 0.002825021743774414, 0.0025119781494140625, 0.0029671192169189453, 0.002928018569946289, 0.002892017364501953, 0.00639796257019043, 0.0025680065155029297, 0.0028090476989746094, 0.002933979034423828, 0.0033020973205566406, 0.003885030746459961, 0.0033419132232666016, 0.002568960189819336, 0.0025529861450195312, 0.0028760433197021484, 0.002847909927368164, 0.002521038055419922, 0.002671957015991211, 0.002611875534057617, 0.0025420188903808594, 0.0029709339141845703, 0.0025980472564697266, 0.0027208328247070312, 0.003339052200317383, 0.0031671524047851562, 0.004388093948364258, 0.002585172653198242, 0.0036890506744384766, 0.002593994140625, 0.002671957015991211, 0.0024399757385253906, 0.002583026885986328, 0.002460002899169922, 0.00397491455078125, 0.0025641918182373047, 0.003200054168701172, 0.0025680065155029297, 0.003690004348754883, 0.005914926528930664, 0.004436969757080078, 0.005671977996826172, 0.00435185432434082, 0.0032439231872558594, 0.0038068294525146484, 0.004305124282836914, 0.0039141178131103516, 0.00255584716796875, 0.004064083099365234, 0.003278970718383789, 0.006021022796630859, 0.005707979202270508, 0.005764007568359375, 0.004393100738525391, 0.004096031188964844, 0.0029311180114746094, 0.004111051559448242, 0.0044460296630859375, 0.002664804458618164, 0.0049021244049072266, 0.002869129180908203, 0.002752065658569336, 0.0029709339141845703, 0.003699064254760742, 0.00681614875793457, 0.005396127700805664, 0.0030961036682128906, 0.0038421154022216797, 0.002928018569946289, 0.0028600692749023438, 0.0028409957885742188, 0.0028150081634521484, 0.003167867660522461, 0.0029921531677246094, 0.003030061721801758, 0.0046160221099853516, 0.0026340484619140625, 0.002624988555908203, 0.003280162811279297, 0.002489805221557617, 0.002618074417114258, 0.0030870437622070312, 0.0029709339141845703, 0.0025899410247802734, 0.002535104751586914, 0.003451824188232422, 0.0033562183380126953, 0.002574920654296875, 0.0025300979614257812, 0.003818035125732422, 0.0025191307067871094, 0.0025300979614257812, 0.0025420188903808594, 0.003509044647216797, 0.0026128292083740234, 0.002608060836791992, 0.003846883773803711, 0.0030879974365234375, 0.003133058547973633, 0.004429817199707031, 0.0027680397033691406, 0.002769947052001953, 0.0025649070739746094, 0.002610921859741211, 0.002727985382080078, 0.003568887710571289, 0.0026009082794189453, 0.0027251243591308594, 0.003695011138916 ...
# 244 0.014915781920073463

# %%
ssim_tmp = []
#print ssim[0].data.cpu().numpy()[0]
for i in range(len(ssim)):
    ssim_tmp.append(ssim[i].data.cpu().numpy()[0])
#print ssim_tmp
np.save(os.path.join(opt.eval_dir, "psnr.npy"), psnr)
np.save(os.path.join(opt.eval_dir, "ssim.npy"), ssim_tmp)

s = np.load(os.path.join(opt.eval_dir, "ssim.npy"))
p = np.load(os.path.join(opt.eval_dir, "psnr.npy"))
print s.size, p.size
print s
print ssim
# Out:
# 244 244
# [0.47781494 0.43329963 0.3342373  0.3327878  0.70980066 0.3654462
#  0.60616595 0.36899504 0.3136771  0.42293277 0.3027359  0.55297124
#  0.38609046 0.4021718  0.6002045  0.36817762 0.44297576 0.396913
#  0.42642096 0.34386697 0.40278804 0.5285475  0.509858   0.34337878
#  0.49067256 0.31302547 0.3813199  0.41302076 0.51902854 0.5138504
#  0.5482495  0.5581454  0.36425292 0.29265252 0.5211884  0.39268583
#  0.50024426 0.38993314 0.36985856 0.47908875 0.5032304  0.29878843
#  0.41463014 0.33173573 0.52971804 0.36280036 0.50544244 0.33991563
#  0.37110215 0.37617847 0.44744092 0.5060992  0.4736998  0.33111584
#  0.4188926  0.65168834 0.2918025  0.47215784 0.5868749  0.4768651
#  0.36913633 0.55280364 0.29167965 0.33295003 0.38133946 0.47418287
#  0.43252906 0.39876363 0.40673012 0.5265573  0.42249063 0.31260455
#  0.36426198 0.55915046 0.4392343  0.3034012  0.566916   0.3538673
#  0.49221054 0.3377267  0.38493884 0.4423349  0.5200705  0.296323
#  0.41843688 0.35755607 0.36650828 0.37563044 0.4966811  0.5477315
#  0.3873694  0.4354345  0.3291974  0.29297605 0.46780416 0.42416131
#  0.28966153 0.30430079 0.40002155 0.32689843 0.3930659  0.34232214
#  0.476427   0.43978953 0.35823366 0.42671636 0.5933018  0.30287778
#  0.33675376 0.57065547 0.58540636 0.48690316 0.37444937 0.44304082
#  0.55035543 0.5025034  0.2682352  0.40074757 0.38797274 0.308005
#  0.35653305 0.42244157 0.26395154 0.63199633 0.5798301  0.42273968
#  0.61133045 0.36835557 0.51691884 0.35399976 0.33313793 0.56746465
#  0.44646838 0.46268725 0.4094321  0.41681945 0.2882635  0.3275432
#  0.57716507 0.37326834 0.35235843 0.57645726 0.3459786  0.32216993
#  0.572851   0.31278753 0.5712806  0.35684037 0.5029968  0.4567934
#  0.537317   0.47752237 0.361935   0.37815857 0.42439926 0.48188853
#  0.4234485  0.4756249  0.3484581  0.5115459  0.36441088 0.35472038
#  0.43251145 0.3057824  0.38573003 0.51526433 0.27976128 0.6036154
#  0.24232608 0.38676885 0.36779234 0.59684384 0.30234936 0.5060423
#  0.32008025 0.4733153  0.6044796  0.4509574  0.3581952  0.42570505
#  0.38978598 0.3917476  0.4232914  0.3491551  0.37234554 0.36811277
#  0.48703077 0.37707725 0.37811014 0.33955714 0.35581926 0.48190573
#  0.5287802  0.40254778 0.45575774 0.6295659  0.27018848 0.38858896
#  0.5571103  0.5550831  0.4043289  0.35166797 0.55860937 0.554238
#  0.29893228 0.29653952 0.5575063  0.5602854  0.2864437  0.2985593
#  0.39801636 0.35076675 0.30373955 0.30470172 0.3207539  0.3801198
#  0.47468135 0.37298435 0.35004237 0.5094697  0.46340838 0.39237985
#  0.44725594 0.46231896 0.4636033  0.27636173 0.32953718 0.37351775
#  0.45975456 0.38151407 0.48709363 0.41832313 0.52299166 0.5590381
#  0.5881409  0.50278217 0.36273867 0.3855163  0.336392   0.36515906
#  0.41845188 0.33808786 0.4213624  0.32226697]
# [Variable containing:
#  0.4778
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4333
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3342
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3328
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.7098
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3654
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.6062
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3690
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3137
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4229
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3027
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5530
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3861
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4022
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.6002
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3682
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4430
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3969
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4264
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3439
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4028
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5285
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5099
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3434
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4907
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3130
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3813
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4130
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5190
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5139
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5482
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5581
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3643
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2927
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5212
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3927
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5002
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3899
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3699
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4791
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5032
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2988
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4146
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3317
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5297
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3628
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5054
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3399
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3711
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3762
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4474
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5061
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4737
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3311
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4189
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.6517
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2918
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4722
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5869
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4769
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3691
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5528
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2917
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3330
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3813
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4742
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4325
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3988
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4067
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5266
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4225
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3126
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3643
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5592
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4392
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3034
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5669
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3539
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4922
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3377
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3849
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4423
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5201
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2963
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4184
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3576
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3665
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3756
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4967
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5477
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3874
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4354
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3292
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2930
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4678
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4242
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2897
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3043
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4000
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3269
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3931
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3423
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4764
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4398
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3582
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4267
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5933
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3029
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3368
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5707
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5854
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4869
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3744
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4430
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5504
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5025
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2682
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4007
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3880
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3080
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3565
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4224
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2640
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.6320
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5798
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4227
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.6113
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3684
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5169
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3540
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3331
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5675
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4465
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4627
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4094
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4168
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2883
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3275
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5772
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3733
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3524
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5765
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3460
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3222
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5729
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3128
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5713
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3568
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5030
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4568
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5373
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4775
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3619
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3782
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4244
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4819
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4234
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4756
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3485
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5115
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3644
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3547
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4325
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3058
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3857
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5153
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2798
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.6036
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2423
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3868
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3678
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5968
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3023
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5060
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3201
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4733
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.6045
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4510
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3582
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4257
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3898
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3917
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4233
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3492
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3723
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3681
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4870
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3771
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3781
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3396
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3558
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4819
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5288
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4025
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4558
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.6296
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2702
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3886
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5571
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5551
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4043
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3517
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5586
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5542
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2989
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2965
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5575
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5603
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2864
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2986
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3980
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3508
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3037
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3047
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3208
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3801
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4747
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3730
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3500
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5095
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4634
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3924
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4473
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4623
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4636
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.2764
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3295
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3735
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4598
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3815
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4871
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4183
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5230
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5590
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5881
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.5028
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3627
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3855
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3364
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3652
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4185
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3381
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.4214
# [torch.FloatTensor of size 1]
# , Variable containing:
#  0.3223
# [torch.FloatTensor of size 1]
# ]

# %%
viz.line(Y=psnr_tmp, opts=dict(showlegend=True))
# Out:
# u'window_3626776a8c095e'

# %%
np.random.rand(10).size
psnr_tmp = np.array(psnr)
print psnr_tmp.size
# Out:
# 244

# %%
import scipy.misc

if opt.dataset == 'test':
    from datasets.testset import testset
    testset = testset('/home/guang/datasets/starcraft_scene2', N=opt.num_images_per_batch)
    dataset = torch.utils.data.DataLoader(
                testset,
                batch_size=opt.num_images_per_batch,
                num_workers=int(1),
                shuffle=True)
    n_image_pairs = len(testset)
    print('Test images in total: {}').format(n_image_pairs)

input_tensor = Tensor(1, 3, 1920, 1072)
target_tensor = Tensor(1, 3, 1920, 1072)
# label_fake = Variable(Tensor(opt.batch_size).fill_(0))
# label_real = Variable(Tensor(opt.batch_size).fill_(1))

i_tmp, t_tmp, o_tmp, os_tmp = [], [], [], []

for minibatch_i, data in enumerate(dataset):

    # Stacking crops together as different inputs/targets
    if minibatch_i > 0:
        break
    input_data = []
    target_data = []
    for crop_i in range(opt.num_crops_per_image):
        input_data.append(data[crop_i*2])
        target_data.append(data[crop_i*2+1])
    input_data = torch.cat(input_data, dim=0)    
    target_data = torch.cat(target_data, dim=0)
    
    input_tensor.resize_(input_data.size()).copy_(input_data)
    target_tensor.resize_(target_data.size()).copy_(target_data)

    
    input = Variable(input_tensor)
    target = Variable(target_tensor)
    
    crop_h, crop_w = 360, 640
    output = model_G.forward(input)
    os_tmp = output
    #output = center_crop(output, crop_h, crop_w)
    output = output.data.cpu().numpy()
    
    i_tmp, t_tmp = input.data.cpu().numpy(), target.data.cpu().numpy()
    
    mean = [ 0.5, 0.5, 0.5 ]
    std = [ 0.5, 0.5, 0.5 ]
    for c in range(3):
        pass
        output[:, c, :, :] *= std[c]
        output[:, c, :, :] += mean[c]
    o_tmp = output    
    
    for save_i in range(opt.num_images_per_batch):
        im_np = output[save_i,:,:,:]
        scipy.misc.imsave(os.path.join(opt.save_dir, opt.snapshot_subdir, 'test_{}.bmp'.format(minibatch_i*opt.num_crops_per_image+save_i)), im_np )
# Out:
# Test images in total: 244

# %%
import numpy
import math

def PSNR(img1, img2):
    mse = numpy.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

# %%
p = PSNR(o_tmp, t_tmp)
print p

print(SSIM(os_tmp, target))

ssim_loss = SSIM(window_size = 11)

print(ssim_loss(os_tmp, target))
# Out:
# 51.2505619128
# Variable containing:
#  0.5022
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
# Variable containing:
#  0.5022
# [torch.cuda.FloatTensor of size 1 (GPU 0)]

# %%
import torch
import torch.nn.functional as F
from torch.autograd import Variable
import numpy as np
from math import exp

def gaussian(window_size, sigma):
    gauss = torch.Tensor([exp(-(x - window_size//2)**2/float(2*sigma**2)) for x in range(window_size)])
    return gauss/gauss.sum()

def create_window(window_size, channel):
    _1D_window = gaussian(window_size, 1.5).unsqueeze(1)
    _2D_window = _1D_window.mm(_1D_window.t()).float().unsqueeze(0).unsqueeze(0)
    window = Variable(_2D_window.expand(channel, 1, window_size, window_size).contiguous())
    return window

def _ssim(img1, img2, window, window_size, channel, size_average = True):
    mu1 = F.conv2d(img1, window, padding = window_size//2, groups = channel)
    mu2 = F.conv2d(img2, window, padding = window_size//2, groups = channel)

    mu1_sq = mu1.pow(2)
    mu2_sq = mu2.pow(2)
    mu1_mu2 = mu1*mu2

    sigma1_sq = F.conv2d(img1*img1, window, padding = window_size//2, groups = channel) - mu1_sq
    sigma2_sq = F.conv2d(img2*img2, window, padding = window_size//2, groups = channel) - mu2_sq
    sigma12 = F.conv2d(img1*img2, window, padding = window_size//2, groups = channel) - mu1_mu2

    C1 = 0.01**2
    C2 = 0.03**2

    ssim_map = ((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*(sigma1_sq + sigma2_sq + C2))

    if size_average:
        return ssim_map.mean()
    else:
        return ssim_map.mean(1).mean(1).mean(1)

def SSIM(img1, img2, window_size = 11, size_average = True):
    (_, channel, _, _) = img1.size()
    window = create_window(window_size, channel)
    
    if img1.is_cuda:
        window = window.cuda(img1.get_device())
    window = window.type_as(img1)
    
    return _ssim(img1, img2, window, window_size, channel, size_average)
